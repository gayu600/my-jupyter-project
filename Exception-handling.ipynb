# %% [markdown]
# # Exception Handling

# %%
# 1. try :  this block may contain error
# 2. except  :  this block will execute if error occurs.
# 3. else : if there is no error, this block will execute.
# 4. finally : irrespective of error, this block will execute.

# %%
# WAP to Display reciprocal of a number.

num = int(input("Enter a Number  :"))

reci = 1/num

print("Reciprocal :",reci)
# Out:
# Enter a Number  : 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 # WAP to Display reciprocal of a number.
#       3 num = int(input("Enter a Number  :"))
# ----> 5 reci = 1/num
#       7 print("Reciprocal :",reci)
#
# ZeroDivisionError: division by zero
